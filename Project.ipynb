# %%
# !pip install objaverse
# Out:
# ...
#   Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 560.5 kB/s eta 0:00:000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 46.8 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 MB 19.3 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 10.9 MB/s eta 0:00:00
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=79afa298eaabafd45e9c137973ccbef4fa3423dce9da0424b7432b23d37adb47
#   Stored in directory: /rhome/ge97lav/.cache/pip/wheels/ba/03/bb/7a97840eb54479b328672e15a536e49dc60da200fb21564d53
# Successfully built gputil
# ...

# %%
import objaverse.xl as oxl

datadir = '/cluster/53/ge97lav/project/data/objaverse/'
uids = 
print(len(uids), type(uids))
# Out:
# 798759 <class 'list'>

# %%
annotations = objaverse.load_annotations(uids[:10])
annotations
sampled_df = annotations.groupby(''
# Out:
# {'8476c4170df24cf5bbe6967222d1a42d': {'uri': 'https://api.sketchfab.com/v3/models/8476c4170df24cf5bbe6967222d1a42d',
#   'uid': '8476c4170df24cf5bbe6967222d1a42d',
#   'name': 'Iain_Dawson_Kew_Road_Formby',
#   'staffpickedAt': None,
#   'viewCount': 4,
#   'likeCount': 0,
#   'animationCount': 0,
#   'viewerUrl': 'https://sketchfab.com/3d-models/8476c4170df24cf5bbe6967222d1a42d',
#   'embedUrl': 'https://sketchfab.com/models/8476c4170df24cf5bbe6967222d1a42d/embed',
#   'commentCount': 0,
#   'isDownloadable': True,
#   'publishedAt': '2021-03-18T09:36:25.430631',
#   'tags': [{'name': 'stair',
#     'slug': 'stair',
#     'uri': 'https://api.sketchfab.com/v3/tags/stair'},
#    {'name': 'staircase',
#     'slug': 'staircase',
#     'uri': 'https://api.sketchfab.com/v3/tags/staircase'},
#    {'name': 'staircon',
#     'slug': 'staircon',
#     'uri': 'https://api.sketchfab.com/v3/tags/staircon'}],
#   'categories': [],
# ...

# %%
#downloading objects
import multiprocessing
import random

RANDOM_NUM_SAMPLES = 100
processes = multiprocessing.cpu_count() #16


random.seed(42)

uids = objaverse.load_uids()
random_object_uids = random.sample(uids, RANDOM_NUM_SAMPLES)

objects = objaverse.load_objects(uids, processes - 2)
# Out:
# 16

# %%
# !python train_generation.py --dataroot /cluster/53/ge97lav/project/data/ShapeNetCore.v2.PC15k/  --model ./output/train_generation/2024-08-06-15-07-54/epoch_1099.pth
#--bs 1 --saveIter 1000 --diagIter 500 --vizIter 500  
#--model /cluster/53/ge97lav/project/output/train_generation/2024-07-21-16-01-46/epoch_99.pth
#import os
#os.getcwd()
# Out:
# Total number of data:4612
# Min number of points: (train)2048 (test)2048
# Total number of data:662
# Min number of points: (train)2048 (test)2048
# Random Seed:  42
# Total number of data:4612
# Min number of points: (train)2048 (test)2048
# Total number of data:662
# Min number of points: (train)2048 (test)2048
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# !python test_generation.py --dataroot /cluster/53/ge97lav/project/data/ShapeNetCore.v2.PC15k --model /cluster/53/ge97lav/project/output/train_generation/overfitted_model/epoch_4999.pth
# Out:
# Jitting Chamfer 3D
# Loaded JIT 3D CUDA chamfer distance
# Random Seed:  42
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 1.10.2
